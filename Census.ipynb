# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\Ritesh\Downloads\population.csv")
df
# Out:
#     Rank                        State             Capital   Population  \
# 0      1                Uttar Pradesh             Lucknow  199,812,341
# 1      2                  Maharashtra              Mumbai  112,374,333
# 2      3                        Bihar               Patna  104,099,452
# 3      4                  West Bengal             Kolkata   91,276,115
# 4      5               Andhra Pradesh           Hyderabad   84,580,777
# 5      6               Madhya Pradesh              Bhopal   72,626,809
# 6      7                   Tamil Nadu             Chennai   72,147,030
# 7      8                    Rajasthan              Jaipur   68,548,437
# 8      9                    Karnataka           Bengaluru   61,095,297
# 9     10                      Gujarat         Gandhinagar   60,439,692
# 10    11                       Odisha        Bhubaneshwar   41,974,218
# 11    12                       Kerala  Thiruvananthapuram   33,406,061
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   35 non-null     int64
#  1   State                  35 non-null     object
#  2   Capital                34 non-null     object
#  3   Population             35 non-null     object
#  4   % of Total Population  35 non-null     float64
#  5   Males                  35 non-null     object
#  6   Females                35 non-null     object
#  7   Sex Ratio              35 non-null     object
#  8   Literacy Rate (%)      35 non-null     float64
#  9   Rural Population       35 non-null     object
#  10  Urban Population       35 non-null     object
#  11  Area (km*km)           35 non-null     object
#  12  Density (1/km*km)      35 non-null     object
#  13  Decadal Growth (%)     35 non-null     object
# dtypes: float64(2), int64(1), object(11)
# ...

# %%
df['Rural Population'].str.split(",")
# Out:
# 0     [155, 111, 022]
# 1      [61, 545, 441]
# 2      [92, 075, 028]
# 3      [62, 213, 676]
# 4      [56, 361, 702]
# 5      [52, 537, 899]
# 6      [37, 189, 229]
# 7      [51, 540, 236]
# 8      [37, 552, 529]
# 9      [34, 670, 817]
# 10     [34, 951, 234]
# 11     [17, 445, 506]
# 12     [25, 036, 946]
# 13     [26, 780, 526]
# 14     [17, 316, 800]
# 15     [19, 603, 658]
# 16     [16, 531, 493]
# 17         [944, 727]
# 18      [9, 134, 820]
# 19      [7, 025, 583]
# 20      [6, 167, 805]
# 21      [2, 710, 051]
# 22      [2, 368, 971]
# 23      [1, 899, 624]
# 24      [1, 406, 861]
# 25         [551, 414]
# 26      [1, 069, 165]
# 27         [394, 341]
# 28         [529, 037]
# 29          [29, 004]
# 30         [455, 962]
# 31         [244, 411]
# 32         [183, 024]
# 33          [60, 331]
# 34          [14, 121]
# Name: Rural Population, dtype: object

# %%
df.columns
# Out:
# Index(['Rank', 'State', 'Capital', 'Population', '% of Total Population',
#        'Males', 'Females', 'Sex Ratio', 'Literacy Rate (%)',
#        'Rural Population', 'Urban Population', 'Area (km*km)',
#        'Density (1/km*km)', 'Decadal Growth (%)'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['State'] = le.fit_transform(df['State'])
df['State']
# Out:
# 0     32
# 1     20
# 2      4
# 3     34
# 4      1
# 5     19
# 6     30
# 7     28
# 8     16
# 9     11
# 10    25
# 11    17
# 12    15
# 13     3
# 14    27
# 15     6
# 16    12
# 17     9
# 18    14
# 19    33
# 20    13
# 21    31
# 22    22
# 23    21
# 24    24
# 25    10
# 26     2
# 27    26
# 28    23
# 29     5
# 30    29
# 31     0
# 32     7
# 33     8
# 34    18
# Name: State, dtype: int32

# %%
df['Growth'] = df['Decadal Growth (%)'].str.split("%").str[0]
df['Growth']
# Out:
# 0      20.1
# 1      16.0
# 2      25.1
# 3      13.9
# 4     10.98
# 5      20.3
# 6      15.6
# 7      21.4
# 8      15.7
# 9      19.2
# 10     14.0
# 11      4.9
# 12     22.3
# 13     16.9
# 14     13.7
# 15     22.6
# 16     19.9
# 17       21
# 18     23.7
# 19     19.2
# 20     12.8
# 21     14.7
# 22     27.8
# 23     18.7
# 24     −0.5
# 25      8.2
# 26     25.9
# 27     27.7
# 28     22.8
# 29     17.1
# 30     12.4
# 31      6.7
# 32     55.5
# 33     53.5
# 34      6.2
# Name: Growth, dtype: object

# %%
df.isna().sum()
# Out:
# Rank                     0
# State                    0
# Capital                  1
# Population               0
# % of Total Population    0
# Males                    0
# Females                  0
# Sex Ratio                0
# Literacy Rate (%)        0
# Rural Population         0
# Urban Population         0
# Area (km*km)             0
# Density (1/km*km)        0
# Decadal Growth (%)       0
# Growth                   0
# dtype: int64

# %%
df = df.dropna()
df.isna().sum()
# Out:
# Rank                     0
# State                    0
# Capital                  0
# Population               0
# % of Total Population    0
# Males                    0
# Females                  0
# Sex Ratio                0
# Literacy Rate (%)        0
# Rural Population         0
# Urban Population         0
# Area (km*km)             0
# Density (1/km*km)        0
# Decadal Growth (%)       0
# Growth                   0
# dtype: int64

# %%
df
# Out:
#     Rank  State             Capital   Population  % of Total Population  \
# 0      1     32             Lucknow  199,812,341                  16.50
# 1      2     20              Mumbai  112,374,333                   9.28
# 2      3      4               Patna  104,099,452                   8.60
# 3      4     34             Kolkata   91,276,115                   7.54
# 4      5      1           Hyderabad   84,580,777                   6.99
# 5      6     19              Bhopal   72,626,809                   6.00
# 6      7     30             Chennai   72,147,030                   5.96
# 7      8     28              Jaipur   68,548,437                   5.66
# 8      9     16           Bengaluru   61,095,297                   5.05
# 9     10     11         Gandhinagar   60,439,692                   4.99
# 10    11     25        Bhubaneshwar   41,974,218                   3.47
# 11    12     17  Thiruvananthapuram   33,406,061                   2.76
# ...

# %%
df.drop(24,axis = 0,inplace = True)
# Out:
# C:\Users\Ritesh\AppData\Local\Temp\ipykernel_4208\550203869.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(24,axis = 0,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 0 to 34
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   33 non-null     int64
#  1   State                  33 non-null     int32
#  2   Capital                33 non-null     object
#  3   Population             33 non-null     object
#  4   % of Total Population  33 non-null     float64
#  5   Males                  33 non-null     object
#  6   Females                33 non-null     object
#  7   Sex Ratio              33 non-null     object
#  8   Literacy Rate (%)      33 non-null     float64
#  9   Rural Population       33 non-null     object
#  10  Urban Population       33 non-null     object
#  11  Area (km*km)           33 non-null     object
#  12  Density (1/km*km)      33 non-null     object
#  13  Decadal Growth (%)     33 non-null     object
# ...

# %%
df['Growth'].astype(float)
# Out:
# 0     20.10
# 1     16.00
# 2     25.10
# 3     13.90
# 4     10.98
# 5     20.30
# 6     15.60
# 7     21.40
# 8     15.70
# 9     19.20
# 10    14.00
# 11     4.90
# 12    22.30
# 13    16.90
# 14    13.70
# 15    22.60
# 16    19.90
# 17    21.00
# 19    19.20
# 20    12.80
# 21    14.70
# 22    27.80
# 23    18.70
# 25     8.20
# 26    25.90
# 27    27.70
# 28    22.80
# 29    17.10
# 30    12.40
# 31     6.70
# 32    55.50
# 33    53.50
# 34     6.20
# Name: Growth, dtype: float64

# %%
df['Growth'].sort
# Out:
# array(['20.1', '16.0', '25.1', '13.9', '10.98', '20.3', '15.6', '21.4',
#        '15.7', '19.2', '14.0', '4.9', '22.3', '16.9', '13.7', '22.6',
#        '19.9', '21', '12.8', '14.7', '27.8', '18.7', '8.2', '25.9',
#        '27.7', '22.8', '17.1', '12.4', '6.7', '55.5', '53.5', '6.2'],
#       dtype=object)

# %%
plt.figure(figsize = (12,6))
plt.bar(df['State'],df['Growth'])
plt.xlabel("State")
plt.ylabel("Growth")
# Out:
# Text(0, 0.5, 'Growth')

# %% [markdown]
# Observation :

# %%
df
# Out:
#     Rank  State             Capital   Population  % of Total Population  \
# 0      1     32             Lucknow  199,812,341                  16.50
# 1      2     20              Mumbai  112,374,333                   9.28
# 2      3      4               Patna  104,099,452                   8.60
# 3      4     34             Kolkata   91,276,115                   7.54
# 4      5      1           Hyderabad   84,580,777                   6.99
# 5      6     19              Bhopal   72,626,809                   6.00
# 6      7     30             Chennai   72,147,030                   5.96
# 7      8     28              Jaipur   68,548,437                   5.66
# 8      9     16           Bengaluru   61,095,297                   5.05
# 9     10     11         Gandhinagar   60,439,692                   4.99
# 10    11     25        Bhubaneshwar   41,974,218                   3.47
# 11    12     17  Thiruvananthapuram   33,406,061                   2.76
# ...

# %%
df['Urban Population'] = pd.to_numeric(df['Urban Population'].str.replace(',', ''))
df['Rural Population'] = pd.to_numeric(df['Rural Population'].str.replace(',', ''))
# Out:
# C:\Users\Ritesh\AppData\Local\Temp\ipykernel_4208\4147050915.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Urban Population'] = pd.to_numeric(df['Urban Population'].str.replace(',', ''))
# C:\Users\Ritesh\AppData\Local\Temp\ipykernel_4208\4147050915.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rural Population'] = pd.to_numeric(df['Rural Population'].str.replace(',', ''))

# %%
df['Urban-Rural Ratio'] = df['Urban Population'] / df['Rural Population']
# Out:
# C:\Users\Ritesh\AppData\Local\Temp\ipykernel_4208\1932757123.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Urban-Rural Ratio'] = df['Urban Population'] / df['Rural Population']

# %%
df
# Out:
#     Rank  State             Capital   Population  % of Total Population  \
# 0      1     32             Lucknow  199,812,341                  16.50
# 1      2     20              Mumbai  112,374,333                   9.28
# 2      3      4               Patna  104,099,452                   8.60
# 3      4     34             Kolkata   91,276,115                   7.54
# 4      5      1           Hyderabad   84,580,777                   6.99
# 5      6     19              Bhopal   72,626,809                   6.00
# 6      7     30             Chennai   72,147,030                   5.96
# 7      8     28              Jaipur   68,548,437                   5.66
# 8      9     16           Bengaluru   61,095,297                   5.05
# 9     10     11         Gandhinagar   60,439,692                   4.99
# 10    11     25        Bhubaneshwar   41,974,218                   3.47
# 11    12     17  Thiruvananthapuram   33,406,061                   2.76
# ...

# %% [markdown]
# Daman has Growth of 55.35% and Urban to Rural Ratio >1
# Dadra and Nagar Haveli has Growth 53.5% and Urban to Rural Ratio close to 1
# Pondicherry has growth of 27.7 and Urban To Rural Population >1

# %%
corr = df.corr()
ax = sns.heatmap(corr,vmin=-1, vmax=1, center=0,cmap=sns.diverging_palette(20, 220, n=200),square=True)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45,horizontalalignment='right');
